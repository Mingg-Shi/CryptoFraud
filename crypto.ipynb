# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("transaction_dataset.csv") #9841 rows
df1.drop(columns=['Unnamed: 0', 'Index'], inplace = True) # drop the first two columns cause unique
df1.dtypes
# Out:
# Address                                                  object
# FLAG                                                      int64
# Avg min between sent tnx                                float64
# Avg min between received tnx                            float64
# Time Diff between first and last (Mins)                 float64
# Sent tnx                                                  int64
# Received Tnx                                              int64
# Number of Created Contracts                               int64
# Unique Received From Addresses                            int64
# Unique Sent To Addresses                                  int64
# min value received                                      float64
# max value received                                      float64
# avg val received                                        float64
# min val sent                                            float64
# max val sent                                            float64
# avg val sent                                            float64
# min value sent to contract                              float64
# max val sent to contract                                float64
# avg value sent to contract                              float64
# total transactions (including tnx to create contract      int64
# total Ether sent                                        float64
# total ether received                                    float64
# total ether sent contracts                              float64
# total ether balance                                     float64
#  Total ERC20 tnxs                                       float64
#  ERC20 total Ether received                             float64
#  ERC20 total ether sent                                 float64
#  ERC20 total Ether sent contract                        float64
#  ERC20 uniq sent addr                                   float64
#  ERC20 uniq rec addr                                    float64
#  ERC20 uniq sent addr.1                                 float64
#  ERC20 uniq rec contract addr                           float64
#  ERC20 avg time between sent tnx                        float64
#  ERC20 avg time between rec tnx                         float64
#  ERC20 avg time between rec 2 tnx                       float64
#  ERC20 avg time between contract tnx                    float64
#  ERC20 min val rec                                      float64
#  ERC20 max val rec                                      float64
#  ERC20 avg val rec                                      float64
#  ERC20 min val sent                                     float64
#  ERC20 max val sent                                     float64
#  ERC20 avg val sent                                     float64
#  ERC20 min val sent contract                            float64
#  ERC20 max val sent contract                            float64
#  ERC20 avg val sent contract                            float64
#  ERC20 uniq sent token name                             float64
#  ERC20 uniq rec token name                              float64
#  ERC20 most sent token type                              object
#  ERC20_most_rec_token_type                               object
# dtype: object

# %%
# Turn object variables into 'category' dtype for more computation efficiency
categories = df1.select_dtypes('O').columns.astype('category')
df1[categories]
# Out:
#                                          Address  ERC20 most sent token type  \
# 0     0x00009277775ac7d0d59eaad8fee3d10ac6c805e8                   Cofoundit
# 1     0x0002b44ddb1476db43c868bd494422ee4c136fed              Livepeer Token
# 2     0x0002bda54cb772d040f779e88eb453cac0daa244                        None
# 3     0x00038e6ba2fd5c09aedb96697c8d7b8fa6632e5e                      Raiden
# 4     0x00062d1dd1afb6fb02540ddad9cdebfe568e0d89               StatusNetwork
# ...                                          ...                         ...
# 9836  0xff481ca14e6c16b79fc8ab299b4d2387ec8ecdd2
# 9837  0xff718805bb9199ebf024ab6acd333e603ad77c85
# 9838  0xff8e6af02d41a576a0c82f7835535193e1a6bccc
# 9839  0xffde23396d57e10abf58bd929bb1e856c7718218                         NaN
# 9840  0xd624d046edbdef805c5e4140dce5fb5ec1b39a3c
#
#              ERC20_most_rec_token_type
# 0                            Numeraire
# 1                       Livepeer Token
# 2                                XENON
# 3                                XENON
# 4                                  EOS
# ...                                ...
# 9836                        GSENetwork
# 9837             Blockwell say NOTSAFU
# 9838  Free BOB Tokens - BobsRepair.com
# 9839                               NaN
# 9840                        INS Promo1
#
# [9841 rows x 3 columns]

# %%
df1.describe()
# Out:
#               FLAG  Avg min between sent tnx  Avg min between received tnx  \
# count  9841.000000               9841.000000                   9841.000000
# mean      0.221421               5086.878721                   8004.851184
# std       0.415224              21486.549974                  23081.714801
# min       0.000000                  0.000000                      0.000000
# 25%       0.000000                  0.000000                      0.000000
# 50%       0.000000                 17.340000                    509.770000
# 75%       0.000000                565.470000                   5480.390000
# max       1.000000             430287.670000                 482175.490000
#
#        Time Diff between first and last (Mins)      Sent tnx  Received Tnx  \
# count                             9.841000e+03   9841.000000   9841.000000
# mean                              2.183333e+05    115.931714    163.700945
# std                               3.229379e+05    757.226361    940.836550
# min                               0.000000e+00      0.000000      0.000000
# 25%                               3.169300e+02      1.000000      1.000000
# 50%                               4.663703e+04      3.000000      4.000000
# 75%                               3.040710e+05     11.000000     27.000000
# max                               1.954861e+06  10000.000000  10000.000000
#
#        Number of Created Contracts  Unique Received From Addresses  \
# count                  9841.000000                     9841.000000
# mean                      3.729702                       30.360939
# std                     141.445583                      298.621112
# min                       0.000000                        0.000000
# 25%                       0.000000                        1.000000
# 50%                       0.000000                        2.000000
# 75%                       0.000000                        5.000000
# max                    9995.000000                     9999.000000
#
#        Unique Sent To Addresses  min value received  ...   ERC20 max val rec  \
# count               9841.000000         9841.000000  ...        9.012000e+03
# mean                  25.840159           43.845153  ...        1.252524e+08
# std                  263.820410          325.929139  ...        1.053741e+10
# min                    0.000000            0.000000  ...        0.000000e+00
# 25%                    1.000000            0.001000  ...        0.000000e+00
# 50%                    2.000000            0.095856  ...        0.000000e+00
# 75%                    3.000000            2.000000  ...        9.900000e+01
# max                 9287.000000        10000.000000  ...        1.000000e+12
#
#         ERC20 avg val rec   ERC20 min val sent   ERC20 max val sent  \
# count        9.012000e+03         9.012000e+03         9.012000e+03
# mean         4.346203e+06         1.174126e+04         1.303594e+07
# std          2.141192e+08         1.053567e+06         1.179905e+09
# min          0.000000e+00         0.000000e+00         0.000000e+00
# 25%          0.000000e+00         0.000000e+00         0.000000e+00
# 50%          0.000000e+00         0.000000e+00         0.000000e+00
# 75%          2.946467e+01         0.000000e+00         0.000000e+00
# max          1.724181e+10         1.000000e+08         1.120000e+11
#
#         ERC20 avg val sent   ERC20 min val sent contract  \
# count         9.012000e+03                        9012.0
# mean          6.318389e+06                           0.0
# std           5.914764e+08                           0.0
# min           0.000000e+00                           0.0
# 25%           0.000000e+00                           0.0
# 50%           0.000000e+00                           0.0
# 75%           0.000000e+00                           0.0
# max           5.614756e+10                           0.0
#
#         ERC20 max val sent contract   ERC20 avg val sent contract  \
# count                        9012.0                        9012.0
# mean                            0.0                           0.0
# std                             0.0                           0.0
# min                             0.0                           0.0
# 25%                             0.0                           0.0
# 50%                             0.0                           0.0
# 75%                             0.0                           0.0
# max                             0.0                           0.0
#
#         ERC20 uniq sent token name   ERC20 uniq rec token name
# count                  9012.000000                 9012.000000
# mean                      1.384931                    4.826676
# std                       6.735121                   16.678607
# min                       0.000000                    0.000000
# 25%                       0.000000                    0.000000
# 50%                       0.000000                    1.000000
# 75%                       0.000000                    2.000000
# max                     213.000000                  737.000000
#
# [8 rows x 46 columns]

# %% [markdown]
# From the above, the mean of some of these variables which should be non-negative(>=0) are 0. This highly suggests that the values of these columns are 0. To try and identify these variables, run through the columns(excluding the label itself) and print out the ones with 2 or less than 1 values.

# %%
for c in df1.columns:
    if df1[c].unique().__len__() <= 2 and c!='FLAG':
        print(c,'unique values:', df1[c].unique())
# Out:
#  ERC20 avg time between sent tnx unique values: [ 0. nan]
#  ERC20 avg time between rec tnx unique values: [ 0. nan]
#  ERC20 avg time between rec 2 tnx unique values: [ 0. nan]
#  ERC20 avg time between contract tnx unique values: [ 0. nan]
#  ERC20 min val sent contract unique values: [ 0. nan]
#  ERC20 max val sent contract unique values: [ 0. nan]
#  ERC20 avg val sent contract unique values: [ 0. nan]

# %%
no_var = df1.var() == 0
df1.var()[no_var].index
# Out:
# /var/folders/96/5lhdzdnj22v9lw7wxwdddk0r0000gn/T/ipykernel_1278/1926140449.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   no_var = df1.var() == 0
# /var/folders/96/5lhdzdnj22v9lw7wxwdddk0r0000gn/T/ipykernel_1278/1926140449.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.var()[no_var].index
# Index([' ERC20 avg time between sent tnx', ' ERC20 avg time between rec tnx',
#        ' ERC20 avg time between rec 2 tnx',
#        ' ERC20 avg time between contract tnx', ' ERC20 min val sent contract',
#        ' ERC20 max val sent contract', ' ERC20 avg val sent contract'],
#       dtype='object')

# %% [markdown]
# This also explains why the variance of these variables are 0. Drop these three columns as they are most likely actually supposed to be null for every row(0 used to replace NaN in certained rows when the person was keying in the data), meaning they give us no information at all.

# %%
cols = [' ERC20 min val sent contract',
' ERC20 max val sent contract', 
' ERC20 avg val sent contract',
' ERC20 avg time between rec 2 tnx',
' ERC20 avg time between contract tnx',
' ERC20 avg time between sent tnx',
' ERC20 avg time between rec tnx']
df1.drop(columns=cols, inplace=True)
df1.describe()
# Out:
#               FLAG  Avg min between sent tnx  Avg min between received tnx  \
# count  9841.000000               9841.000000                   9841.000000
# mean      0.221421               5086.878721                   8004.851184
# std       0.415224              21486.549974                  23081.714801
# min       0.000000                  0.000000                      0.000000
# 25%       0.000000                  0.000000                      0.000000
# 50%       0.000000                 17.340000                    509.770000
# 75%       0.000000                565.470000                   5480.390000
# max       1.000000             430287.670000                 482175.490000
#
#        Time Diff between first and last (Mins)      Sent tnx  Received Tnx  \
# count                             9.841000e+03   9841.000000   9841.000000
# mean                              2.183333e+05    115.931714    163.700945
# std                               3.229379e+05    757.226361    940.836550
# min                               0.000000e+00      0.000000      0.000000
# 25%                               3.169300e+02      1.000000      1.000000
# 50%                               4.663703e+04      3.000000      4.000000
# 75%                               3.040710e+05     11.000000     27.000000
# max                               1.954861e+06  10000.000000  10000.000000
#
#        Number of Created Contracts  Unique Received From Addresses  \
# count                  9841.000000                     9841.000000
# mean                      3.729702                       30.360939
# std                     141.445583                      298.621112
# min                       0.000000                        0.000000
# 25%                       0.000000                        1.000000
# 50%                       0.000000                        2.000000
# 75%                       0.000000                        5.000000
# max                    9995.000000                     9999.000000
#
#        Unique Sent To Addresses  min value received  ...  \
# count               9841.000000         9841.000000  ...
# mean                  25.840159           43.845153  ...
# std                  263.820410          325.929139  ...
# min                    0.000000            0.000000  ...
# 25%                    1.000000            0.001000  ...
# 50%                    2.000000            0.095856  ...
# 75%                    3.000000            2.000000  ...
# max                 9287.000000        10000.000000  ...
#
#         ERC20 uniq sent addr.1   ERC20 uniq rec contract addr  \
# count              9012.000000                    9012.000000
# mean                  0.003440                       4.901909
# std                   0.065698                      17.246576
# min                   0.000000                       0.000000
# 25%                   0.000000                       0.000000
# 50%                   0.000000                       1.000000
# 75%                   0.000000                       2.000000
# max                   3.000000                     782.000000
#
#         ERC20 min val rec   ERC20 max val rec   ERC20 avg val rec  \
# count         9012.000000        9.012000e+03        9.012000e+03
# mean           485.614688        1.252524e+08        4.346203e+06
# std          16883.278712        1.053741e+10        2.141192e+08
# min              0.000000        0.000000e+00        0.000000e+00
# 25%              0.000000        0.000000e+00        0.000000e+00
# 50%              0.000000        0.000000e+00        0.000000e+00
# 75%              0.001523        9.900000e+01        2.946467e+01
# max         990000.000000        1.000000e+12        1.724181e+10
#
#         ERC20 min val sent   ERC20 max val sent   ERC20 avg val sent  \
# count         9.012000e+03         9.012000e+03         9.012000e+03
# mean          1.174126e+04         1.303594e+07         6.318389e+06
# std           1.053567e+06         1.179905e+09         5.914764e+08
# min           0.000000e+00         0.000000e+00         0.000000e+00
# 25%           0.000000e+00         0.000000e+00         0.000000e+00
# 50%           0.000000e+00         0.000000e+00         0.000000e+00
# 75%           0.000000e+00         0.000000e+00         0.000000e+00
# max           1.000000e+08         1.120000e+11         5.614756e+10
#
#         ERC20 uniq sent token name   ERC20 uniq rec token name
# count                  9012.000000                 9012.000000
# mean                      1.384931                    4.826676
# std                       6.735121                   16.678607
# min                       0.000000                    0.000000
# 25%                       0.000000                    0.000000
# 50%                       0.000000                    1.000000
# 75%                       0.000000                    2.000000
# max                     213.000000                  737.000000
#
# [8 rows x 39 columns]

# %%
df1['FLAG'].value_counts() #imbalanced
# Out:
# 0    7662
# 1    2179
# Name: FLAG, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Notice how a lot of the rows with na values are actually flagged as fraud

# %% [markdown]
# Observe how only columns involving data related to ERC20 is missing.
# ##### What is ERC20?
# ERC-20 allows <b>different</b> smart-contract enabled tokens a way to be exchanged. Tokens, in this regard, are a representation of an asset, right, ownership, access, cryptocurrency, or anything else that is not unique in and of itself but can be transferred. The standard allows tokens representing one of these factors—along with smart contracts—to be exchanged for a token that represents another. Smart contracts are conditions written into the coding that execute different aspects of a transaction between parties.
#
# ERC-20 guides the creation of new tokens on the Ethereum blockchain so that they are interchangeable with other tokens used within smart contracts.
#
# ##### What's the Difference Between ETH and ERC-20?
# Ether (ETH) is the native token used by the Ethereum blockchain and network as a payment system for verifying transactions. ERC-20 is the standard for creating smart contract-enabled fungible tokens to be used in the Ethereum ecosystem.
# In this dataset, ERC-20 most likely refers to tokens which are ERC-20 compliant
#
# We may suspect that transactions involving tokens which aren't ERC-20 compliant are often associated with fraud

# %%
cols_NA_counts = df1.isnull().sum()
cols_NA_counts
# Out:
# Address                                                   0
# FLAG                                                      0
# Avg min between sent tnx                                  0
# Avg min between received tnx                              0
# Time Diff between first and last (Mins)                   0
# Sent tnx                                                  0
# Received Tnx                                              0
# Number of Created Contracts                               0
# Unique Received From Addresses                            0
# Unique Sent To Addresses                                  0
# min value received                                        0
# max value received                                        0
# avg val received                                          0
# min val sent                                              0
# max val sent                                              0
# avg val sent                                              0
# min value sent to contract                                0
# max val sent to contract                                  0
# avg value sent to contract                                0
# total transactions (including tnx to create contract      0
# total Ether sent                                          0
# total ether received                                      0
# total ether sent contracts                                0
# total ether balance                                       0
#  Total ERC20 tnxs                                       829
#  ERC20 total Ether received                             829
#  ERC20 total ether sent                                 829
#  ERC20 total Ether sent contract                        829
#  ERC20 uniq sent addr                                   829
#  ERC20 uniq rec addr                                    829
#  ERC20 uniq sent addr.1                                 829
#  ERC20 uniq rec contract addr                           829
#  ERC20 min val rec                                      829
#  ERC20 max val rec                                      829
#  ERC20 avg val rec                                      829
#  ERC20 min val sent                                     829
#  ERC20 max val sent                                     829
#  ERC20 avg val sent                                     829
#  ERC20 uniq sent token name                             829
#  ERC20 uniq rec token name                              829
#  ERC20 most sent token type                             841
#  ERC20_most_rec_token_type                              851
# dtype: int64

# %%
cols_with_NA = cols_NA_counts.where(lambda x : x > 0).dropna()
print(cols_with_NA)
# Out:
#  Total ERC20 tnxs                   829.0
#  ERC20 total Ether received         829.0
#  ERC20 total ether sent             829.0
#  ERC20 total Ether sent contract    829.0
#  ERC20 uniq sent addr               829.0
#  ERC20 uniq rec addr                829.0
#  ERC20 uniq sent addr.1             829.0
#  ERC20 uniq rec contract addr       829.0
#  ERC20 min val rec                  829.0
#  ERC20 max val rec                  829.0
#  ERC20 avg val rec                  829.0
#  ERC20 min val sent                 829.0
#  ERC20 max val sent                 829.0
#  ERC20 avg val sent                 829.0
#  ERC20 uniq sent token name         829.0
#  ERC20 uniq rec token name          829.0
#  ERC20 most sent token type         841.0
#  ERC20_most_rec_token_type          851.0
# dtype: float64

# %%
erc20_cols = cols_with_NA.index
df1[df1[erc20_cols].isna().all(axis=1)]
# Out:
#                                          Address  FLAG  \
# 7662  0x0020731604c882cf7bf8c444be97d17b19ea4316     1
# 7666  0x005b9f4516f8e640bbe48136901738b323c53b00     1
# 7675  0x0153775362c3071c1860e8dbfd53ccc82fa226f5     1
# 7676  0x015f17e2851ea392351b7f259e4cfd03dc443cef     1
# 7678  0x0167409e6106ec3e3f05a09fcf04606918d21ad5     1
# ...                                          ...   ...
# 9831  0xfe9b7db8d9d57e9ad9341bcf51b110ba5d27b48b     1
# 9833  0xff0e20e3a7575d823302bbb27e233c23f2c3070b     1
# 9834  0xff2f6c6fbd71a078f1c1781855467d30897b5a33     1
# 9835  0xff35866acb80ce4b169d1460cd48108955c1c445     1
# 9839  0xffde23396d57e10abf58bd929bb1e856c7718218     1
#
#       Avg min between sent tnx  Avg min between received tnx  \
# 7662                   1457.31                         34.12
# 7666                      0.00                          0.00
# 7675                      0.00                          0.00
# 7676                      0.00                          0.00
# 7678                    259.52                          2.60
# ...                        ...                           ...
# 9831                    193.09                         81.82
# 9833                      0.00                          0.00
# 9834                      0.00                         49.51
# 9835                      0.00                          0.00
# 9839                      0.00                          0.00
#
#       Time Diff between first and last (Mins)  Sent tnx  Received Tnx  \
# 7662                                  4815.43         3            13
# 7666                                     0.00         0             0
# 7675                                 15432.58         1             1
# 7676                                     0.00         0             1
# 7678                                  4417.03        17             2
# ...                                       ...       ...           ...
# 9831                                  1485.80         6             4
# 9833                                     0.00         0             0
# 9834                                 12643.85         1            15
# 9835                                  8427.92         0             1
# 9839                                     0.00         0             1
#
#       Number of Created Contracts  Unique Received From Addresses  \
# 7662                            0                              10
# 7666                            0                               0
# 7675                            0                               1
# 7676                            0                               1
# 7678                            5                               2
# ...                           ...                             ...
# 9831                            0                               3
# 9833                            0                               0
# 9834                            0                              15
# 9835                            1                               1
# 9839                            0                               1
#
#       Unique Sent To Addresses  ...   ERC20 min val rec   ERC20 max val rec  \
# 7662                         3  ...                 NaN                 NaN
# 7666                         0  ...                 NaN                 NaN
# 7675                         1  ...                 NaN                 NaN
# 7676                         0  ...                 NaN                 NaN
# 7678                         6  ...                 NaN                 NaN
# ...                        ...  ...                 ...                 ...
# 9831                         6  ...                 NaN                 NaN
# 9833                         0  ...                 NaN                 NaN
# 9834                         1  ...                 NaN                 NaN
# 9835                         0  ...                 NaN                 NaN
# 9839                         0  ...                 NaN                 NaN
#
#        ERC20 avg val rec   ERC20 min val sent   ERC20 max val sent  \
# 7662                 NaN                  NaN                  NaN
# 7666                 NaN                  NaN                  NaN
# 7675                 NaN                  NaN                  NaN
# 7676                 NaN                  NaN                  NaN
# 7678                 NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 9831                 NaN                  NaN                  NaN
# 9833                 NaN                  NaN                  NaN
# 9834                 NaN                  NaN                  NaN
# 9835                 NaN                  NaN                  NaN
# 9839                 NaN                  NaN                  NaN
#
#        ERC20 avg val sent   ERC20 uniq sent token name  \
# 7662                  NaN                          NaN
# 7666                  NaN                          NaN
# 7675                  NaN                          NaN
# 7676                  NaN                          NaN
# 7678                  NaN                          NaN
# ...                   ...                          ...
# 9831                  NaN                          NaN
# 9833                  NaN                          NaN
# 9834                  NaN                          NaN
# 9835                  NaN                          NaN
# 9839                  NaN                          NaN
#
#        ERC20 uniq rec token name   ERC20 most sent token type  \
# 7662                         NaN                          NaN
# 7666                         NaN                          NaN
# 7675                         NaN                          NaN
# 7676                         NaN                          NaN
# 7678                         NaN                          NaN
# ...                          ...                          ...
# 9831                         NaN                          NaN
# 9833                         NaN                          NaN
# 9834                         NaN                          NaN
# 9835                         NaN                          NaN
# 9839                         NaN                          NaN
#
#        ERC20_most_rec_token_type
# 7662                         NaN
# 7666                         NaN
# 7675                         NaN
# 7676                         NaN
# 7678                         NaN
# ...                          ...
# 9831                         NaN
# 9833                         NaN
# 9834                         NaN
# 9835                         NaN
# 9839                         NaN
#
# [829 rows x 42 columns]

# %%
df1[df1[erc20_cols].isna().all(axis=1)]['FLAG'].value_counts()
# Out:
# 1    829
# Name: FLAG, dtype: int64

# %% [markdown]
# - Based on these information, we can create a new feature that is 1 if that row NA value for ALL variables related to ERC20 and 0 if it doesn't.
# - Name of the feature can be called "ERC-20 info all NA" since it just so happens that the NA values lie in features that give information about transactions involving ERC-20 compliant tokens

# %%
df1['ERC-20 info all NA'] = df1.isnull().any(axis=1).apply(lambda x: int(x))

# %% [markdown]
# #### Take a look at correlations (end up quite useless except for one variable)

# %%
df1.corr()['FLAG'][2:].dropna().apply(lambda x: (abs(x),'+ve' if x > 0 else '-ve')).sort_values(ascending=False)
# Out:
# ERC-20 info all NA                                          (0.553403780887705, +ve)
# Time Diff between first and last (Mins)                    (0.2693537569722309, -ve)
# Avg min between received tnx                               (0.1185333698301473, -ve)
# total transactions (including tnx to create contract      (0.10028896008507175, -ve)
# Received Tnx                                              (0.07931619280730286, -ve)
# Sent tnx                                                  (0.07800602196583913, -ve)
# avg val sent                                               (0.0635562890151814, -ve)
# Unique Sent To Addresses                                  (0.04558386884087186, -ve)
# Unique Received From Addresses                            (0.03194102392769172, -ve)
#  Total ERC20 tnxs                                        (0.025696890085446983, -ve)
#  ERC20 min val sent                                       (0.02536415408744808, +ve)
#  ERC20 avg val sent                                       (0.02504351016185665, +ve)
#  ERC20 max val sent                                      (0.025038127044248428, +ve)
#  ERC20 total ether sent                                  (0.024762246540287657, +ve)
# max val sent                                              (0.02243674280280961, -ve)
# min value received                                       (0.021640797251753642, -ve)
#  ERC20 uniq sent addr                                    (0.020554062220193046, -ve)
# max value received                                       (0.019258646759397282, -ve)
#  ERC20 uniq rec contract addr                            (0.018526673480888087, -ve)
#  ERC20 uniq rec token name                               (0.018047086565521762, -ve)
#  ERC20 uniq rec addr                                     (0.017539153099104938, -ve)
# total ether received                                      (0.01690025928156377, -ve)
# total Ether sent                                          (0.01499297496687596, -ve)
# Number of Created Contracts                               (0.01371129953782957, -ve)
#  ERC20 total Ether sent contract                         (0.013513926756410726, +ve)
# avg val received                                         (0.011880855998158324, -ve)
#  ERC20 min val rec                                       (0.011163151587451004, +ve)
#  ERC20 uniq sent token name                              (0.009249422989911372, +ve)
# avg value sent to contract                               (0.008882703157640752, -ve)
# total ether sent contracts                               (0.007987781519506635, -ve)
# max val sent to contract                                 (0.007987771374366005, -ve)
#  ERC20 avg val rec                                       (0.007881428267691263, +ve)
# min value sent to contract                               (0.007212966241721193, -ve)
# min val sent                                             (0.006626248484049224, +ve)
#  ERC20 total Ether received                              (0.004474950731202962, -ve)
#  ERC20 max val rec                                       (0.004313011269473587, -ve)
# total ether balance                                      (0.003229164821540691, -ve)
#  ERC20 uniq sent addr.1                                 (0.0030471330561018363, -ve)
# Name: FLAG, dtype: object

# %% [markdown]
# Fraud transactions have shorter average time gap between each transaction by the same frauder

# %%
sns.kdeplot(data = df1[df1['FLAG']==0], x='Time Diff between first and last (Mins)')
sns.kdeplot(data = df1[df1['FLAG']==1], x='Time Diff between first and last (Mins)')
plt.legend(['non-fraud','fraud'])

# %% [markdown]
# ##### Look at the dimension of each feature

# %%
df1.nunique()
# Out:
# Address                                                 9816
# FLAG                                                       2
# Avg min between sent tnx                                5013
# Avg min between received tnx                            6223
# Time Diff between first and last (Mins)                 7810
# Sent tnx                                                 641
# Received Tnx                                             727
# Number of Created Contracts                               20
# Unique Received From Addresses                           256
# Unique Sent To Addresses                                 258
# min value received                                      4589
# max value received                                      6302
# avg val received                                        6767
# min val sent                                            4719
# max val sent                                            6647
# avg val sent                                            5854
# min value sent to contract                                 3
# max val sent to contract                                   4
# avg value sent to contract                                 4
# total transactions (including tnx to create contract     897
# total Ether sent                                        5868
# total ether received                                    6728
# total ether sent contracts                                 4
# total ether balance                                     5717
#  Total ERC20 tnxs                                        300
#  ERC20 total Ether received                             3460
#  ERC20 total ether sent                                 1415
#  ERC20 total Ether sent contract                          29
#  ERC20 uniq sent addr                                    107
#  ERC20 uniq rec addr                                     147
#  ERC20 uniq sent addr.1                                    4
#  ERC20 uniq rec contract addr                            123
#  ERC20 min val rec                                      1276
#  ERC20 max val rec                                      2647
#  ERC20 avg val rec                                      3380
#  ERC20 min val sent                                      476
#  ERC20 max val sent                                     1130
#  ERC20 avg val sent                                     1309
#  ERC20 uniq sent token name                               70
#  ERC20 uniq rec token name                               121
#  ERC20 most sent token type                              305
#  ERC20_most_rec_token_type                               467
# ERC-20 info all NA                                         2
# dtype: int64

# %%
df1.drop(columns=['Address'],inplace=True) #drop address as it is a categorical variable with too many unique values

# %% [markdown]
# ##### Handling NA in numerical features

# %%
# Replace missings of numerical variables with median
df1.fillna(df1.median(), inplace=True)
# Out:
# /var/folders/96/5lhdzdnj22v9lw7wxwdddk0r0000gn/T/ipykernel_1278/3099460311.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.fillna(df1.median(), inplace=True)

# %%
# Recheck the Correlation matrix
corr = df1.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)]=True
with sns.axes_style('white'):
    fig, ax = plt.subplots(figsize=(18,10))
    sns.heatmap(corr,  mask=mask, annot=False, cmap='CMRmap', center=0, linewidths=0.1, square=True)

# %% [markdown]
# For every two features that are highly correlated with each other and FLAG is not one of it, choose one of the two to drop

# %%
drop = [' ERC20 total ether sent',' ERC20 total Ether received', 'total ether sent contracts',' ERC20 uniq rec contract addr',
' ERC20 min val sent','avg value sent to contract', ' ERC20 avg val sent', 'Received Tnx', ' ERC20 max val rec',
' ERC20 uniq sent token name', 'total transactions (including tnx to create contract',' Total ERC20 tnxs','total ether received',
'Unique Sent To Addresses','min val sent',' ERC20 uniq sent addr.1','total ether balance'] #dropping 17 cols
df1.drop(columns=drop, inplace=True, axis=1)

# %%
corr = df1.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)]=True
with sns.axes_style('white'):
    fig, ax = plt.subplots(figsize=(18,10))
    sns.heatmap(corr,  mask=mask, annot=False, cmap='CMRmap', center=0, linewidths=0.1, square=True)

# %% [markdown]
# ##### Take a look at the dimensions of the features again

# %%
df1.nunique()
# Out:
# FLAG                                          2
# Avg min between sent tnx                   5013
# Avg min between received tnx               6223
# Time Diff between first and last (Mins)    7810
# Sent tnx                                    641
# Number of Created Contracts                  20
# Unique Received From Addresses              256
# min value received                         4589
# max value received                         6302
# avg val received                           6767
# max val sent                               6647
# avg val sent                               5854
# min value sent to contract                    3
# max val sent to contract                      4
# total Ether sent                           5868
#  ERC20 total Ether sent contract             29
#  ERC20 uniq sent addr                       107
#  ERC20 uniq rec addr                        147
#  ERC20 min val rec                         1276
#  ERC20 avg val rec                         3380
#  ERC20 max val sent                        1130
#  ERC20 uniq rec token name                  121
#  ERC20 most sent token type                 305
#  ERC20_most_rec_token_type                  467
# ERC-20 info all NA                            2
# dtype: int64

# %% [markdown]
# Take a closer look at the features with a very low dimension

# %%
df1['min value sent to contract'].value_counts()
# Out:
# 0.00    9839
# 0.02       1
# 0.01       1
# Name: min value sent to contract, dtype: int64

# %%
df1['max val sent to contract'].value_counts()
# Out:
# 0.000000    9838
# 0.020000       1
# 0.010000       1
# 0.046029       1
# Name: max val sent to contract, dtype: int64

# %% [markdown]
# Drop these columns as most observations are valued at 0

# %%
drop = ['min value sent to contract','max val sent to contract', ' ERC20 total Ether sent contract']
df1.drop(columns=drop, inplace=True)

# %%
df1.groupby(by=['FLAG','Number of Created Contracts']).size()
# Out:
# FLAG  Number of Created Contracts
# 0     0                              6491
#       1                              1140
#       2                                 8
#       3                                 6
#       4                                 2
#       5                                 2
#       6                                 1
#       16                                1
#       19                                1
#       41                                1
#       1180                              1
#       2096                              1
#       2404                              1
#       2550                              1
#       3128                              1
#       3521                              1
#       3900                              1
#       6453                              1
#       9995                              1
# 1     0                              1994
#       1                               180
#       3                                 1
#       4                                 2
#       5                                 1
#       7                                 1
# dtype: int64

# %% [markdown]
# Set a cap on 'Number of Created Contracts' to 1, but don't drop it as its not largely 0. Also name it differently now.

# %%
df1['hasCreatedContracts'] = df1['Number of Created Contracts'].apply(lambda x: x if x < 1 else 1)
df1.groupby(by=['FLAG','hasCreatedContracts']).size()
# Out:
# FLAG  hasCreatedContracts
# 0     0                      6491
#       1                      1171
# 1     0                      1994
#       1                       185
# dtype: int64

# %% [markdown]
# Take a look at the Nominal variables

# %%
df1.groupby(by=['FLAG',' ERC20 most sent token type']).size().get(1).sort_values(ascending=False)
# Out:
#  ERC20 most sent token type
#                                  1191
# blockwell.ai KYC Casper Token      33
# Tronix                             14
# OmiseGO                             7
# VeChain                             5
#                                  ...
# Lucky Token                         1
# Magna                               1
# Merculet                            1
# Brickblock                          1
# minereum                            1
# Length: 78, dtype: int64

# %%
df1.groupby(by=['FLAG',' ERC20 most sent token type']).size().get(0).sort_values(ascending=False)
# Out:
#  ERC20 most sent token type
# 0                                      4399
# None                                   1856
# EOS                                     135
# OmiseGO                                 130
# Golem                                   126
#                                        ...
# Opus                                      1
# DNA                                       1
# PangeaCoinICO                             1
# DAPSTOKEN                                 1
# LocalCoinSwap dividend token 2019Q1       1
# Length: 262, dtype: int64

# %%
df1.groupby(by=['FLAG',' ERC20_most_rec_token_type']).size().get(1).sort_values(ascending=False).index
df1[' ERC20_most_rec_token_type']=df1[' ERC20_most_rec_token_type'].apply(lambda x: 'Unknown' if x in ['',' ',"''",'NaN', None,'0',np.NaN,np.NAN,'None',np.nan] else x)

# %% [markdown]
# Notice how some names actually likely meant NA, but are labelled in different ways. We can try and identify these different labels and group them together

# %%
df1[' ERC20 most sent token type']=df1[' ERC20 most sent token type'].apply(lambda x: 'Unknown' if x in ['',' ',"''",'NaN', None,'0',np.NaN,np.NAN,'None'] else x)
#Relabel all those that are missing but labelled differently under the name "Unknown"
df1[' ERC20 most sent token type']=df1[' ERC20 most sent token type'].apply(lambda x: 'Unknown' if x in ['',' ',"''",'NaN', None,'0',np.NaN,np.NAN,'None'] else x)

# %%
df1[df1['FLAG']==1].describe()
# Out:
#          FLAG  Avg min between sent tnx  Avg min between received tnx  \
# count  2179.0               2179.000000                   2179.000000
# mean      1.0               3888.109780                   2874.712639
# std       0.0              17505.367743                  10624.453455
# min       1.0                  0.000000                      0.000000
# 25%       1.0                  0.000000                      0.000000
# 50%       1.0                  0.000000                     82.070000
# 75%       1.0                434.095000                    694.700000
# max       1.0             262976.000000                 194451.330000
#
#        Time Diff between first and last (Mins)     Sent tnx  \
# count                              2179.000000  2179.000000
# mean                              55230.057953     5.173933
# std                              107518.118553    21.884569
# min                                   0.000000     0.000000
# 25%                                   0.000000     0.000000
# 50%                                7545.430000     1.000000
# 75%                               48303.700000     2.000000
# max                              933778.820000   472.000000
#
#        Number of Created Contracts  Unique Received From Addresses  \
# count                  2179.000000                     2179.000000
# mean                      0.093162                       12.475906
# std                       0.356037                       69.380810
# min                       0.000000                        0.000000
# 25%                       0.000000                        1.000000
# 50%                       0.000000                        3.000000
# 75%                       0.000000                        9.000000
# max                       7.000000                     2001.000000
#
#        min value received  max value received   avg val received  ...  \
# count         2179.000000          2179.000000       2179.000000  ...
# mean            30.619509            53.383739         36.440837  ...
# std            535.349338           707.310512        557.835910  ...
# min              0.000000             0.000000          0.000000  ...
# 25%              0.000000             0.000000          0.000000  ...
# 50%              0.004463             0.997900          0.500134  ...
# 75%              0.150000             4.990015          1.082389  ...
# max          10000.000000         18998.000000      10000.000000  ...
#
#        avg val sent  total Ether sent   ERC20 uniq sent addr  \
# count   2179.000000       2179.000000            2179.000000
# mean      16.263756         87.373398               0.300138
# std      270.486110       1689.409333               2.086261
# min        0.000000          0.000000               0.000000
# 25%        0.000000          0.000000               0.000000
# 50%        0.499139          0.999139               0.000000
# 75%        3.581926         10.081873               0.000000
# max    10162.666670      70020.000000              54.000000
#
#         ERC20 uniq rec addr   ERC20 min val rec   ERC20 avg val rec  \
# count           2179.000000         2179.000000        2.179000e+03
# mean               2.970170          579.026267        5.183367e+06
# std               10.772995        14346.761152        2.255434e+08
# min                0.000000            0.000000        0.000000e+00
# 25%                1.000000            0.000000        0.000000e+00
# 50%                1.000000            0.000000        1.337000e+00
# 75%                1.000000            1.337000        1.337000e+01
# max              188.000000       567580.000000        1.050000e+10
#
#         ERC20 max val sent   ERC20 uniq rec token name  ERC-20 info all NA  \
# count         2.179000e+03                 2179.000000         2179.000000
# mean          5.167833e+07                    2.926572            0.380450
# std           2.399332e+09                   10.105555            0.485609
# min           0.000000e+00                    0.000000            0.000000
# 25%           0.000000e+00                    1.000000            0.000000
# 50%           0.000000e+00                    1.000000            0.000000
# 75%           0.000000e+00                    1.000000            1.000000
# max           1.120000e+11                  211.000000            1.000000
#
#        hasCreatedContracts
# count          2179.000000
# mean              0.084901
# std               0.278799
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               1.000000
#
# [8 rows x 21 columns]

# %%
df1[df1['FLAG']==0].describe()
# Out:
#          FLAG  Avg min between sent tnx  Avg min between received tnx  \
# count  7662.0               7662.000000                   7662.000000
# mean      0.0               5427.797217                   9463.813842
# std       0.0              22479.761351                  25349.420434
# min       0.0                  0.000000                      0.000000
# 25%       0.0                  0.000000                      0.000000
# 50%       0.0                 22.745000                   1402.135000
# 75%       0.0                651.947500                   7284.062500
# max       0.0             430287.670000                 482175.490000
#
#        Time Diff between first and last (Mins)      Sent tnx  \
# count                             7.662000e+03   7662.000000
# mean                              2.647183e+05    147.430175
# std                               3.477739e+05    855.489695
# min                               0.000000e+00      0.000000
# 25%                               3.206700e+02      1.000000
# 50%                               1.166260e+05      3.000000
# 75%                               3.892398e+05     16.000000
# max                               1.954861e+06  10000.000000
#
#        Number of Created Contracts  Unique Received From Addresses  \
# count                  7662.000000                     7662.000000
# mean                      0.152832                       35.447272
# std                       0.359849                      336.233407
# min                       0.000000                        0.000000
# 25%                       0.000000                        1.000000
# 50%                       0.000000                        2.000000
# 75%                       0.000000                        5.000000
# max                       1.000000                     9999.000000
#
#        min value received  max value received   avg val received  \
# count         7662.000000          7662.000000       7662.000000
# mean            47.606401           656.750247        118.989750
# std            234.310386         14735.674899       3255.859303
# min              0.000000             0.000000          0.000000
# 25%              0.006687             1.303643          0.704126
# 50%              0.157340            12.216789          3.747374
# 75%              8.458613            95.431114         50.500000
# max          10000.000000        800000.000000     283618.831600
#
#         max val sent  avg val sent  total Ether sent   ERC20 uniq rec addr  \
# count    7662.000000   7662.000000      7.662000e+03           7662.000000
# mean      393.932645     52.858578      1.302575e+04              8.200861
# std      7506.075539    228.736821      4.060498e+05             88.539072
# min         0.000000      0.000000      0.000000e+00              0.000000
# 25%         0.544625      0.202771      9.985256e-01              0.000000
# 50%         9.698321      2.309737      3.406226e+01              0.000000
# 75%        85.999005     33.666149      1.009990e+02              2.000000
# max    520000.000000  12000.000000      2.858096e+07           4293.000000
#
#         ERC20 min val rec   ERC20 avg val rec   ERC20 max val sent  \
# count         7662.000000        7.662000e+03         7.662000e+03
# mean           406.507613        3.637878e+06         6.359648e+05
# std          16636.555680        1.986587e+08         1.736030e+07
# min              0.000000        0.000000e+00         0.000000e+00
# 25%              0.000000        0.000000e+00         0.000000e+00
# 50%              0.000000        0.000000e+00         0.000000e+00
# 75%              0.000000        3.072593e+01         0.000000e+00
# max         990000.000000        1.724181e+10         1.000010e+09
#
#         ERC20 uniq rec token name  ERC-20 info all NA
# count                 7662.000000         7662.000000
# mean                     4.953015            0.004046
# std                     17.283054            0.063483
# min                      0.000000            0.000000
# 25%                      0.000000            0.000000
# 50%                      0.000000            0.000000
# 75%                      2.000000            0.000000
# max                    737.000000            1.000000

# %% [markdown]
# Just for the sake of it, look at the dimensions of each variable again after all that processing

# %%
df1.nunique()
# Out:
# FLAG                                          2
# Avg min between sent tnx                   5013
# Avg min between received tnx               6223
# Time Diff between first and last (Mins)    7810
# Sent tnx                                    641
# Number of Created Contracts                   2
# Unique Received From Addresses              256
# min value received                         4589
# max value received                         6302
# avg val received                           6767
# max val sent                               6647
# avg val sent                               5854
# total Ether sent                           5868
#  ERC20 uniq rec addr                        147
#  ERC20 min val rec                         1276
#  ERC20 avg val rec                         3380
#  ERC20 max val sent                        1130
#  ERC20 uniq rec token name                  121
#  ERC20 most sent token type                 302
#  ERC20_most_rec_token_type                  465
# ERC-20 info all NA                            2
# dtype: int64

# %%
df1.groupby(by=['FLAG','Sent tnx']).size().get(0)
# Out:
# Sent tnx
# 0        1194
# 1         879
# 2        1022
# 3        1190
# 4         335
#          ...
# 9996        5
# 9997        2
# 9998        4
# 9999        4
# 10000       1
# Length: 639, dtype: int64

# %% [markdown]
# ##### Capping numerical variables

# %%
df1['Sent tnx'] = df1['Sent tnx'].apply(lambda x: min(x,20))

# %%
sns.kdeplot(data=df1[df1['FLAG']==1], x='Sent tnx')
sns.kdeplot(data=df1[df1['FLAG']==0], x='Sent tnx')
plt.show()

# %%
df1.describe()
# Out:
#               FLAG  Avg min between sent tnx  Avg min between received tnx  \
# count  9841.000000               9841.000000                   9841.000000
# mean      0.221421               5086.878721                   8004.851184
# std       0.415224              21486.549974                  23081.714801
# min       0.000000                  0.000000                      0.000000
# 25%       0.000000                  0.000000                      0.000000
# 50%       0.000000                 17.340000                    509.770000
# 75%       0.000000                565.470000                   5480.390000
# max       1.000000             430287.670000                 482175.490000
#
#        Time Diff between first and last (Mins)     Sent tnx  \
# count                             9.841000e+03  9841.000000
# mean                              2.183333e+05     6.302815
# std                               3.229379e+05     7.545456
# min                               0.000000e+00     0.000000
# 25%                               3.169300e+02     1.000000
# 50%                               4.663703e+04     3.000000
# 75%                               3.040710e+05    11.000000
# max                               1.954861e+06    20.000000
#
#        Number of Created Contracts  Unique Received From Addresses  \
# count                  9841.000000                     9841.000000
# mean                      3.729702                       30.360939
# std                     141.445583                      298.621112
# min                       0.000000                        0.000000
# 25%                       0.000000                        1.000000
# 50%                       0.000000                        2.000000
# 75%                       0.000000                        5.000000
# max                    9995.000000                     9999.000000
#
#        min value received  max value received   avg val received  ...  \
# count         9841.000000          9841.000000       9841.000000  ...
# mean            43.845153           523.152481        100.711721  ...
# std            325.929139         13008.821539       2885.002236  ...
# min              0.000000             0.000000          0.000000  ...
# 25%              0.001000             1.000000          0.426905  ...
# 50%              0.095856             6.000000          1.729730  ...
# 75%              2.000000            67.067040         22.000000  ...
# max          10000.000000        800000.000000     283618.831600  ...
#
#        avg val sent  total Ether sent   ERC20 uniq sent addr  \
# count   9841.000000      9.841000e+03            9841.000000
# mean      44.755731      1.016092e+04               5.163093
# std      239.080215      3.583227e+05             100.733483
# min        0.000000      0.000000e+00               0.000000
# 25%        0.086184      2.262059e-01               0.000000
# 50%        1.606000      1.248680e+01               0.000000
# 75%       21.999380      1.009990e+02               0.000000
# max    12000.000000      2.858096e+07            6582.000000
#
#         ERC20 uniq rec addr   ERC20 min val rec   ERC20 avg val rec  \
# count           9841.000000         9841.000000        9.841000e+03
# mean               7.042679          444.706794        3.980082e+06
# std               78.317580        16157.005403        2.049048e+08
# min                0.000000            0.000000        0.000000e+00
# 25%                0.000000            0.000000        0.000000e+00
# 50%                1.000000            0.000000        0.000000e+00
# 75%                2.000000            0.000000        1.337000e+01
# max             4293.000000       990000.000000        1.724181e+10
#
#         ERC20 max val sent   ERC20 uniq rec token name  ERC-20 info all NA  \
# count         9.841000e+03                 9841.000000         9841.000000
# mean          1.193780e+07                    4.504319            0.087389
# std           1.129115e+09                   15.995935            0.282419
# min           0.000000e+00                    0.000000            0.000000
# 25%           0.000000e+00                    0.000000            0.000000
# 50%           0.000000e+00                    1.000000            0.000000
# 75%           0.000000e+00                    2.000000            0.000000
# max           1.120000e+11                  737.000000            1.000000
#
#        hasCreatedContracts
# count          9841.000000
# mean              0.137791
# std               0.344698
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               1.000000
#
# [8 rows x 21 columns]

# %%
df1['Avg min between sent tnx'] = df1['Avg min between sent tnx'].apply(lambda x: min(x,210))

# %%
sns.kdeplot(data=df1[df1['FLAG']==1], x='Avg min between sent tnx')
sns.kdeplot(data=df1[df1['FLAG']==0], x='Avg min between sent tnx')
plt.show()

# %%
df1.columns
# Out:
# Index(['FLAG', 'Avg min between sent tnx', 'Avg min between received tnx',
#        'Time Diff between first and last (Mins)', 'Sent tnx',
#        'Number of Created Contracts', 'Unique Received From Addresses',
#        'min value received', 'max value received ', 'avg val received',
#        'max val sent', 'avg val sent', 'total Ether sent',
#        ' ERC20 uniq sent addr', ' ERC20 uniq rec addr', ' ERC20 min val rec',
#        ' ERC20 avg val rec', ' ERC20 max val sent',
#        ' ERC20 uniq rec token name', ' ERC20 most sent token type',
#        ' ERC20_most_rec_token_type', 'ERC-20 info all NA',
#        'hasCreatedContracts'],
#       dtype='object')

# %%
df1['Avg min between received tnx'] = df1['Avg min between received tnx'].apply(lambda x: min(x,1000))

# %%
sns.kdeplot(data=df1[df1['FLAG']==1], x='Avg min between received tnx')
sns.kdeplot(data=df1[df1['FLAG']==0], x='Avg min between received tnx')
plt.show()

# %%
df1['Unique Received From Addresses'] = df1['Unique Received From Addresses'].apply(lambda x: min(x,50))

# %%
sns.kdeplot(data=df1[df1['FLAG']==1], x='Unique Received From Addresses')
sns.kdeplot(data=df1[df1['FLAG']==0], x='Unique Received From Addresses')
plt.show()

# %%
df1[df1['FLAG']==1][' ERC20_most_rec_token_type'].value_counts()
# Out:
# Unknown                          849
# Blockwell say NOTSAFU            779
# GSENetwork                        80
# Livepeer Token                    46
# blockwell.ai KYC Casper Token     39
#                                 ...
# GOT                                1
# BOX Token                          1
# Promodl                            1
# BAX                                1
# INS Promo1                         1
# Name:  ERC20_most_rec_token_type, Length: 135, dtype: int64

# %% [markdown]
# #### Try to minimize dimensionality of Categorical variables

# %%
keep = df1[' ERC20_most_rec_token_type'].value_counts().nlargest(20)

# %% [markdown]
# Again, notice how some names actually likely meant NA, but are labelled in different ways. We can try and identify these different labels and group them together

# %%
df1[' ERC20_most_rec_token_type'] = df1[' ERC20_most_rec_token_type'].apply(lambda x: x if x in keep else 'others')

# %%
df1[' ERC20_most_rec_token_type'].value_counts()
# Out:
# Unknown                             5291
# others                              1296
# OmiseGO                              873
# Blockwell say NOTSAFU                779
# DATAcoin                             358
# Livepeer Token                       207
# EOS                                  161
# XENON                                145
# Golem                                126
# GSENetwork                            80
# Tronix                                76
# blockwell.ai KYC Casper Token         65
# Promodl                               52
# VIU                                   50
# INS Promo                             44
# Bulleon Promo Token                   44
# KickCoin                              43
# StatusNetwork                         42
# Free BOB Tokens - BobsRepair.com      38
# BAT                                   36
# ERC20                                 35
# Name:  ERC20_most_rec_token_type, dtype: int64

# %%
df1[df1['FLAG']==1][' ERC20_most_rec_token_type'].value_counts() #side note: fraud has a large number of Blockwell say NOTSAFU
# Out:
# Unknown                             849
# Blockwell say NOTSAFU               779
# others                              202
# GSENetwork                           80
# Livepeer Token                       46
# blockwell.ai KYC Casper Token        39
# Free BOB Tokens - BobsRepair.com     37
# ERC20                                35
# XENON                                24
# Tronix                               20
# VIU                                  15
# OmiseGO                              13
# INS Promo                            10
# DATAcoin                              8
# Bulleon Promo Token                   7
# KickCoin                              5
# Golem                                 4
# StatusNetwork                         3
# EOS                                   2
# Promodl                               1
# Name:  ERC20_most_rec_token_type, dtype: int64

# %%
df1[df1['FLAG']==0][' ERC20_most_rec_token_type'].value_counts()
# Out:
# Unknown                             4442
# others                              1094
# OmiseGO                              860
# DATAcoin                             350
# Livepeer Token                       161
# EOS                                  159
# Golem                                122
# XENON                                121
# Tronix                                56
# Promodl                               51
# StatusNetwork                         39
# KickCoin                              38
# Bulleon Promo Token                   37
# BAT                                   36
# VIU                                   35
# INS Promo                             34
# blockwell.ai KYC Casper Token         26
# Free BOB Tokens - BobsRepair.com       1
# Name:  ERC20_most_rec_token_type, dtype: int64

# %% [markdown]
# Group those variables of a low frequency under "Others"

# %%
keep = df1[' ERC20 most sent token type'].value_counts().nlargest(8).index

# %%
df1[' ERC20 most sent token type'] = df1[' ERC20 most sent token type'].apply(lambda x: x if x in keep else 'others')

# %%
df1[df1['FLAG']==1][' ERC20 most sent token type'].value_counts()
# Out:
# Unknown                          2021
# others                            108
# blockwell.ai KYC Casper Token      33
# OmiseGO                             7
# Golem                               4
# EOS                                 3
# StatusNetwork                       2
# BAT                                 1
# Name:  ERC20 most sent token type, dtype: int64

# %%
df1[df1['FLAG']==0][' ERC20 most sent token type'].value_counts()
# Out:
# Unknown                          6267
# others                            779
# EOS                               135
# OmiseGO                           130
# Golem                             126
# blockwell.ai KYC Casper Token      95
# StatusNetwork                      59
# BAT                                37
# Qtum                               34
# Name:  ERC20 most sent token type, dtype: int64

# %% [markdown]
# Since data is imbalanced, we need to do resampling as random forests and logistic regression do not handle imbalanced data well. In this case, oversampling is chosen but this can also create other issues which shouldn't be disregarded.
# click [here](https://machinelearningmastery.com/random-oversampling-and-undersampling-for-imbalanced-classification/) to find out more.

# %% [markdown]
# #### TRAIN TEST SPLIT
#
# done before the fiting of scalars and vectorizers to avoid data leakage

# %%
from sklearn.model_selection import train_test_split
X = df1.drop(columns=["FLAG"])
y = df1['FLAG']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority', random_state=42)
X_train, y_train = oversample.fit_resample(X_train, y_train)

# %% [markdown]
# Split continuous from categorical data

# %%
continuous_train = X_train.drop(columns=[' ERC20_most_rec_token_type',' ERC20 most sent token type'])
cat_train = X_train[[' ERC20_most_rec_token_type',' ERC20 most sent token type']]

continuous_test = X_test.drop(columns=[' ERC20_most_rec_token_type',' ERC20 most sent token type'])
cat_test = X_test[[' ERC20_most_rec_token_type',' ERC20 most sent token type']]

# %% [markdown]
# Scale the continuous variables

# %%
non_scale_train = continuous_train[['Sent tnx','Unique Received From Addresses',' ERC20 uniq rec addr',' ERC20 uniq rec token name']]
to_scale_train = continuous_train.drop(columns=['Sent tnx','Unique Received From Addresses',' ERC20 uniq rec addr',' ERC20 uniq rec token name'])
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
scaled_train = scalar.fit_transform(to_scale_train)
scaled_train = pd.DataFrame(scaled_train, columns=to_scale_train.columns)


non_scale_test = continuous_test[['Sent tnx','Unique Received From Addresses',' ERC20 uniq rec addr',' ERC20 uniq rec token name']]
to_scale_test = continuous_test.drop(columns=['Sent tnx','Unique Received From Addresses',' ERC20 uniq rec addr',' ERC20 uniq rec token name'])
scaled_test = scalar.transform(to_scale_test)
# scaled.corrwith(df1['FLAG']).sort_values(ascending=False)

# %% [markdown]
# ##### Plot scatterplots for continuous variables

# %%
fig, axes = plt.subplots(7,2,figsize=(20,50))
cols = scaled_train.columns
scaled_train['FLAG'] = y_train.values
for i in range(14):
    c = cols[i]
    fraud = scaled_train[scaled_train['FLAG']==1][c]
    normal = scaled_train[scaled_train['FLAG']==0][c]
    sns.scatterplot(fraud, ax=axes[i//2][i%2])
    sns.scatterplot(normal,ax=axes[i//2][i%2],alpha=0.2)
    axes[i//2][i%2].legend(['Fraud','normal'])
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder
sent_enc = OneHotEncoder(categories='auto')
sent_vects_train = sent_enc.fit_transform(cat_train[[' ERC20 most sent token type']]).toarray()
sent_vects_test = sent_enc.transform(cat_test[[' ERC20 most sent token type']]).toarray()
rec_enc = OneHotEncoder(categories='auto')
rec_vects_train = rec_enc.fit_transform(cat_train[[' ERC20_most_rec_token_type']]).toarray()
rec_vects_test = rec_enc.transform(cat_test[[' ERC20_most_rec_token_type']]).toarray()

# %%
scaled_train.drop(columns=['FLAG'],inplace=True)

# %%
X_train = np.hstack([scaled_train,non_scale_train,rec_vects_train,sent_vects_train])
X_test = np.hstack([scaled_test,non_scale_test,rec_vects_test,sent_vects_test])

# %%
from sklearn.linear_model import LogisticRegression
# all parameters not specified are set to their defaults
logisticRegr = LogisticRegression(random_state=42,max_iter=1000)
logisticRegr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
from sklearn.metrics import classification_report

# %%
y_train_pred = logisticRegr.predict(X_train)
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train,y_train_pred)
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      5732
#            1       0.97      0.97      0.97      5732
#
#     accuracy                           0.97     11464
#    macro avg       0.97      0.97      0.97     11464
# weighted avg       0.97      0.97      0.97     11464

# %%
y_test_pred = logisticRegr.predict(X_test)
confusion_matrix(y_test,y_test_pred)
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1930
#            1       0.89      0.96      0.92       531
#
#     accuracy                           0.97      2461
#    macro avg       0.94      0.96      0.95      2461
# weighted avg       0.97      0.97      0.97      2461

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(random_state=42)
RF.fit(X_train, y_train)
train_pred = RF.predict(X_train)
test_pred = RF.predict(X_test)

# %%
confusion_matrix(y_train,train_pred)
# Out:
# array([[5732,    0],
#        [   0, 5732]])

# %%
confusion_matrix(y_test,test_pred)
# Out:
# array([[1916,   14],
#        [  22,  509]])

# %%
print(classification_report(y_train, train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5732
#            1       1.00      1.00      1.00      5732
#
#     accuracy                           1.00     11464
#    macro avg       1.00      1.00      1.00     11464
# weighted avg       1.00      1.00      1.00     11464

# %%
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1930
#            1       0.97      0.96      0.97       531
#
#     accuracy                           0.99      2461
#    macro avg       0.98      0.98      0.98      2461
# weighted avg       0.99      0.99      0.99      2461

# %% [markdown]
# Feature importance of RF with default parameters

# %%
feature_names = np.concatenate([scalar.feature_names_in_, 
non_scale_train.columns, 
rec_enc.categories_[0], 
sent_enc.categories_[0]])

# %%
def getWhichFeatureNameUnder(index):
    '''takes in the column index and gets the name of the feature that value falls under'''
    if len(scalar.feature_names_in_) - 1 >= index:
        return scalar.feature_names_in_[index]
    else:
        index -= len(scalar.feature_names_in_)
        if len(non_scale_train.columns) - 1 >= index:
            return non_scale_train.columns[index]
        else:
            index -= len(non_scale_train.columns)
            if len(rec_enc.categories_[0]) - 1 >= index:
                return rec_enc.feature_names_in_[0]
            else:
                return sent_enc.feature_names_in_[0]

# %%
sorted_idx = RF.feature_importances_.argsort()
features_value_pair = [(getWhichFeatureNameUnder(index),feature_names[index]) for index in sorted_idx]
features_value_pair
# Out:
# [(' ERC20 most sent token type', 'Qtum'),
#  (' ERC20_most_rec_token_type', 'StatusNetwork'),
#  (' ERC20_most_rec_token_type', 'Bulleon Promo Token'),
#  (' ERC20 most sent token type', 'StatusNetwork'),
#  (' ERC20 most sent token type', 'BAT'),
#  (' ERC20_most_rec_token_type', 'BAT'),
#  (' ERC20_most_rec_token_type', 'EOS'),
#  (' ERC20 most sent token type', 'OmiseGO'),
#  (' ERC20 most sent token type', 'EOS'),
#  (' ERC20_most_rec_token_type', 'KickCoin'),
#  (' ERC20_most_rec_token_type', 'Promodl'),
#  (' ERC20_most_rec_token_type', 'VIU'),
#  (' ERC20_most_rec_token_type', 'INS Promo'),
#  (' ERC20_most_rec_token_type', 'Tronix'),
#  (' ERC20_most_rec_token_type', 'Livepeer Token'),
#  (' ERC20_most_rec_token_type', 'Golem'),
#  (' ERC20_most_rec_token_type', 'blockwell.ai KYC Casper Token'),
#  (' ERC20 most sent token type', 'Golem'),
#  (' ERC20_most_rec_token_type', 'XENON'),
#  (' ERC20_most_rec_token_type', 'Free BOB Tokens - BobsRepair.com'),
#  (' ERC20_most_rec_token_type', 'ERC20'),
#  (' ERC20 most sent token type', 'others'),
#  (' ERC20_most_rec_token_type', 'GSENetwork'),
#  (' ERC20_most_rec_token_type', 'others'),
#  (' ERC20_most_rec_token_type', 'DATAcoin'),
#  (' ERC20 most sent token type', 'blockwell.ai KYC Casper Token'),
#  (' ERC20 max val sent', ' ERC20 max val sent'),
#  (' ERC20 avg val rec', ' ERC20 avg val rec'),
#  ('hasCreatedContracts', 'hasCreatedContracts'),
#  (' ERC20 most sent token type', 'Unknown'),
#  ('Number of Created Contracts', 'Number of Created Contracts'),
#  ('avg val sent', 'avg val sent'),
#  ('Avg min between sent tnx', 'Avg min between sent tnx'),
#  (' ERC20 uniq sent addr', ' ERC20 uniq sent addr'),
#  (' ERC20_most_rec_token_type', 'Unknown'),
#  ('min value received', 'min value received'),
#  ('max val sent', 'max val sent'),
#  (' ERC20_most_rec_token_type', 'OmiseGO'),
#  ('Sent tnx', 'Sent tnx'),
#  (' ERC20 min val rec', ' ERC20 min val rec'),
#  ('max value received ', 'max value received '),
#  ('Unique Received From Addresses', 'Unique Received From Addresses'),
#  ('total Ether sent', 'total Ether sent'),
#  ('Avg min between received tnx', 'Avg min between received tnx'),
#  (' ERC20_most_rec_token_type', 'Blockwell say NOTSAFU'),
#  ('avg val received', 'avg val received'),
#  ('ERC-20 info all NA', 'ERC-20 info all NA'),
#  ('Time Diff between first and last (Mins)',
#   'Time Diff between first and last (Mins)'),
#  (' ERC20 uniq rec addr', ' ERC20 uniq rec addr'),
#  (' ERC20 uniq rec token name', ' ERC20 uniq rec token name')]

# %%
fig, axes = plt.subplots(figsize=(30,10))
labels = [x[1] + ' UNDER ' + x[0] if x[0] != x[1] else x[0] for x in features_value_pair]
plt.barh(labels[28:], RF.feature_importances_[sorted_idx][28:])
plt.xlabel("Random Forest Feature Importance(top 20)", fontdict={'size':20})
plt.yticks(font={'size':20})
plt.show()

# %%
fig, axes = plt.subplots(figsize=(30,10))
labels = [x[1] + ' UNDER ' + x[0] if x[0] != x[1] else x[0] for x in features_value_pair]
plt.barh(labels[:20], RF.feature_importances_[sorted_idx][:20])
plt.xlabel("Random Forest Feature Importance(bottom 20)", fontdict={'size':20})
plt.yticks(font={'size':20})
plt.show()
